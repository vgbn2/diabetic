# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from collections import deque
import random

# Deque to store data, with a maximum length
# This keeps the graph from becoming too cluttered
max_data_points = 20
xs = deque(maxlen=max_data_points)
ys = deque(maxlen=max_data_points)

# Initialize with some starting data
xs.append(0)
ys.append(0)

# Setup the figure and axes
style.use('fivethirtyeight') # Optional: use a specific style
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)

def animate(i):
    """
    Function to be called at set intervals to update the plot.
    'i' is the current frame number (automatically passed by FuncAnimation).
    """
    # 1. Get new data (example uses random data, replace with real data source)
    new_x = xs[-1] + 1
    new_y = random.randrange(0, 100) # Replace with real data acquisition

    # 2. Append new data to the deques
    xs.append(new_x)
    ys.append(new_y)

    # 3. Clear the previous plot and draw the new one
    ax1.clear()
    ax1.plot(xs, ys)

    # Optional: Add labels and titles
    plt.title('Live Data Feed')
    plt.ylabel('Y Value')
    plt.xlabel('X Value')


# Set up the animation
# interval=1000 means update every 1000 milliseconds (1 second)
ani = animation.FuncAnimation(fig, animate, interval=1000)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 ys.append(0)
#      16 # Setup the figure and axes
# ---> 17 style.use('fivethirtyeight') # Optional: use a specific style
#      18 fig = plt.figure()
#      19 ax1 = fig.add_subplot(1, 1, 1)
#
# NameError: name 'style' is not defined
